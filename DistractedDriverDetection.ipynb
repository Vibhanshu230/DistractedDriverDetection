# %%
# importing all necessary libraries
import os
import pandas as pd
import pickle
import numpy as np
import seaborn as sns
import secrets
import cv2
from PIL import Image
from PIL import ImageFile
from sklearn.datasets import load_files
import matplotlib.pyplot as plt
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
from keras.preprocessing import image                  
from tqdm import tqdm
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import seaborn as sns
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/38/d2/3e8c13ffc37ca5ebc6f382b242b44acb43eb489042e1728407ac3904e72f/opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata
#   Downloading opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\manis\anaconda3\lib\site-packages (from opencv-python) (1.24.3)
# Downloading opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl (38.1 MB)
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.1 MB 1.9 MB/s eta 0:00:20
#    ---------------------------------------- 0.1/38.1 MB 812.7 kB/s eta 0:00:47
#    ---------------------------------------- 0.1/38.1 MB 1.0 MB/s eta 0:00:38
#    ---------------------------------------- 0.2/38.1 MB 1.1 MB/s eta 0:00:34
#    ---------------------------------------- 0.4/38.1 MB 1.6 MB/s eta 0:00:24
#     --------------------------------------- 0.6/38.1 MB 2.2 MB/s eta 0:00:18
#     --------------------------------------- 0.7/38.1 MB 2.2 MB/s eta 0:00:18
#     --------------------------------------- 0.9/38.1 MB 2.6 MB/s eta 0:00:15
#    - -------------------------------------- 1.1/38.1 MB 2.7 MB/s eta 0:00:14
#    - -------------------------------------- 1.2/38.1 MB 2.7 MB/s eta 0:00:14
#    - -------------------------------------- 1.3/38.1 MB 2.7 MB/s eta 0:00:14
#    - -------------------------------------- 1.7/38.1 MB 3.0 MB/s eta 0:00:13
#    - -------------------------------------- 1.9/38.1 MB 3.1 MB/s eta 0:00:12
#    -- ------------------------------------- 2.1/38.1 MB 3.3 MB/s eta 0:00:11
#    -- ------------------------------------- 2.4/38.1 MB 3.4 MB/s eta 0:00:11
#    -- ------------------------------------- 2.6/38.1 MB 3.5 MB/s eta 0:00:11
#    -- ------------------------------------- 2.8/38.1 MB 3.6 MB/s eta 0:00:10
#    --- ------------------------------------ 3.2/38.1 MB 3.8 MB/s eta 0:00:10
#    --- ------------------------------------ 3.4/38.1 MB 4.0 MB/s eta 0:00:09
#    --- ------------------------------------ 3.6/38.1 MB 3.9 MB/s eta 0:00:09
#    ---- ----------------------------------- 3.9/38.1 MB 4.0 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.2/38.1 MB 4.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.6/38.1 MB 4.3 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.7/38.1 MB 4.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 4.8/38.1 MB 4.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 4.9/38.1 MB 4.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 5.1/38.1 MB 4.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.2/38.1 MB 4.0 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.3/38.1 MB 4.0 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.6/38.1 MB 4.0 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.7/38.1 MB 4.0 MB/s eta 0:00:09
#    ------ --------------------------------- 5.8/38.1 MB 4.0 MB/s eta 0:00:09
#    ------ --------------------------------- 5.9/38.1 MB 3.9 MB/s eta 0:00:09
#    ------ --------------------------------- 6.2/38.1 MB 3.9 MB/s eta 0:00:09
#    ------ --------------------------------- 6.6/38.1 MB 4.0 MB/s eta 0:00:08
#    ------- -------------------------------- 7.0/38.1 MB 4.2 MB/s eta 0:00:08
#    ------- -------------------------------- 7.4/38.1 MB 4.3 MB/s eta 0:00:08
#    ------- -------------------------------- 7.5/38.1 MB 4.3 MB/s eta 0:00:08
#    -------- ------------------------------- 8.2/38.1 MB 4.5 MB/s eta 0:00:07
#    -------- ------------------------------- 8.6/38.1 MB 4.6 MB/s eta 0:00:07
#    --------- ------------------------------ 8.9/38.1 MB 4.7 MB/s eta 0:00:07
#    --------- ------------------------------ 9.2/38.1 MB 4.7 MB/s eta 0:00:07
#    ---------- ----------------------------- 9.7/38.1 MB 4.8 MB/s eta 0:00:06
#    ---------- ----------------------------- 9.9/38.1 MB 4.8 MB/s eta 0:00:06
#    ---------- ----------------------------- 10.2/38.1 MB 4.8 MB/s eta 0:00:06
#    ---------- ----------------------------- 10.3/38.1 MB 5.0 MB/s eta 0:00:06
#    ----------- ---------------------------- 10.7/38.1 MB 5.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 10.9/38.1 MB 5.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 11.2/38.1 MB 5.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 11.4/38.1 MB 5.4 MB/s eta 0:00:05
#    ------------ --------------------------- 11.8/38.1 MB 5.6 MB/s eta 0:00:05
#    ------------ --------------------------- 12.0/38.1 MB 5.5 MB/s eta 0:00:05
#    ------------ --------------------------- 12.2/38.1 MB 5.5 MB/s eta 0:00:05
#    ------------- -------------------------- 12.5/38.1 MB 5.5 MB/s eta 0:00:05
#    ------------- -------------------------- 12.5/38.1 MB 5.5 MB/s eta 0:00:05
#    ------------- -------------------------- 12.8/38.1 MB 5.4 MB/s eta 0:00:05
#    ------------- -------------------------- 13.2/38.1 MB 5.5 MB/s eta 0:00:05
#    -------------- ------------------------- 13.8/38.1 MB 5.7 MB/s eta 0:00:05
#    -------------- ------------------------- 14.0/38.1 MB 5.7 MB/s eta 0:00:05
#    -------------- ------------------------- 14.2/38.1 MB 5.6 MB/s eta 0:00:05
#    --------------- ------------------------ 14.5/38.1 MB 5.6 MB/s eta 0:00:05
#    --------------- ------------------------ 14.7/38.1 MB 5.5 MB/s eta 0:00:05
#    --------------- ------------------------ 15.0/38.1 MB 5.7 MB/s eta 0:00:05
#    --------------- ------------------------ 15.2/38.1 MB 5.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 15.6/38.1 MB 6.1 MB/s eta 0:00:04
#    ---------------- ----------------------- 16.0/38.1 MB 6.3 MB/s eta 0:00:04
#    ----------------- ---------------------- 16.2/38.1 MB 6.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 16.5/38.1 MB 6.4 MB/s eta 0:00:04
#    ----------------- ---------------------- 16.9/38.1 MB 6.5 MB/s eta 0:00:04
#    ------------------ --------------------- 17.2/38.1 MB 6.4 MB/s eta 0:00:04
#    ------------------ --------------------- 17.6/38.1 MB 6.5 MB/s eta 0:00:04
#    ------------------ --------------------- 18.0/38.1 MB 6.5 MB/s eta 0:00:04
#    ------------------- -------------------- 18.2/38.1 MB 6.4 MB/s eta 0:00:04
#    ------------------- -------------------- 18.4/38.1 MB 6.2 MB/s eta 0:00:04
#    ------------------- -------------------- 18.8/38.1 MB 6.2 MB/s eta 0:00:04
#    -------------------- ------------------- 19.3/38.1 MB 6.2 MB/s eta 0:00:04
#    -------------------- ------------------- 19.6/38.1 MB 6.3 MB/s eta 0:00:03
#    -------------------- ------------------- 20.0/38.1 MB 6.4 MB/s eta 0:00:03
#    --------------------- ------------------ 20.2/38.1 MB 6.4 MB/s eta 0:00:03
#    --------------------- ------------------ 20.4/38.1 MB 6.2 MB/s eta 0:00:03
#    --------------------- ------------------ 20.7/38.1 MB 6.4 MB/s eta 0:00:03
#    --------------------- ------------------ 20.9/38.1 MB 6.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 21.3/38.1 MB 6.4 MB/s eta 0:00:03
#    ---------------------- ----------------- 21.7/38.1 MB 6.6 MB/s eta 0:00:03
#    ----------------------- ---------------- 22.2/38.1 MB 6.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 22.6/38.1 MB 6.7 MB/s eta 0:00:03
#    ------------------------ --------------- 23.1/38.1 MB 7.2 MB/s eta 0:00:03
#    ------------------------ --------------- 23.4/38.1 MB 7.1 MB/s eta 0:00:03
#    ------------------------ --------------- 23.6/38.1 MB 6.9 MB/s eta 0:00:03
#    ------------------------ --------------- 23.8/38.1 MB 6.8 MB/s eta 0:00:03
#    ------------------------- -------------- 24.0/38.1 MB 6.7 MB/s eta 0:00:03
#    ------------------------- -------------- 24.4/38.1 MB 6.8 MB/s eta 0:00:03
#    ------------------------- -------------- 24.6/38.1 MB 6.8 MB/s eta 0:00:02
#    -------------------------- ------------- 24.8/38.1 MB 6.7 MB/s eta 0:00:02
#    -------------------------- ------------- 25.0/38.1 MB 6.8 MB/s eta 0:00:02
#    -------------------------- ------------- 25.2/38.1 MB 6.5 MB/s eta 0:00:02
#    -------------------------- ------------- 25.4/38.1 MB 6.5 MB/s eta 0:00:02
#    -------------------------- ------------- 25.6/38.1 MB 6.5 MB/s eta 0:00:02
#    --------------------------- ------------ 25.8/38.1 MB 6.5 MB/s eta 0:00:02
#    --------------------------- ------------ 26.1/38.1 MB 6.4 MB/s eta 0:00:02
#    --------------------------- ------------ 26.4/38.1 MB 6.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 26.8/38.1 MB 6.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 26.8/38.1 MB 6.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.5/38.1 MB 6.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 27.9/38.1 MB 6.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 28.1/38.1 MB 6.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 28.5/38.1 MB 6.5 MB/s eta 0:00:02
#    ------------------------------ --------- 28.8/38.1 MB 6.5 MB/s eta 0:00:02
#    ------------------------------ --------- 29.0/38.1 MB 6.5 MB/s eta 0:00:02
#    ------------------------------ --------- 29.4/38.1 MB 6.4 MB/s eta 0:00:02
#    ------------------------------- -------- 29.6/38.1 MB 6.4 MB/s eta 0:00:02
#    ------------------------------- -------- 30.0/38.1 MB 6.4 MB/s eta 0:00:02
#    ------------------------------- -------- 30.1/38.1 MB 6.2 MB/s eta 0:00:02
#    ------------------------------- -------- 30.4/38.1 MB 6.2 MB/s eta 0:00:02
#    -------------------------------- ------- 30.7/38.1 MB 6.4 MB/s eta 0:00:02
#    -------------------------------- ------- 31.2/38.1 MB 6.5 MB/s eta 0:00:02
#    --------------------------------- ------ 31.7/38.1 MB 6.5 MB/s eta 0:00:01
#    --------------------------------- ------ 32.3/38.1 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 32.6/38.1 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.1/38.1 MB 6.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 33.5/38.1 MB 6.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 33.8/38.1 MB 6.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.2/38.1 MB 6.8 MB/s eta 0:00:01
#    ------------------------------------ --- 34.7/38.1 MB 7.0 MB/s eta 0:00:01
#    ------------------------------------ --- 35.1/38.1 MB 7.2 MB/s eta 0:00:01
#    ------------------------------------- -- 35.5/38.1 MB 7.4 MB/s eta 0:00:01
#    ------------------------------------- -- 36.0/38.1 MB 7.7 MB/s eta 0:00:01
#    -------------------------------------- - 36.5/38.1 MB 7.9 MB/s eta 0:00:01
#    -------------------------------------- - 36.7/38.1 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  37.3/38.1 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  37.5/38.1 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  38.1/38.1 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  38.1/38.1 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 38.1/38.1 MB 7.4 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.8.1.78
# Note: you may need to restart the kernel to use updated packages.

# %%
# creating directories for training and testing images 
TEST_DIR = os.path.join(os.getcwd(),"imgs","test")
TRAIN_DIR = os.path.join(os.getcwd(),"imgs","train")
MODEL_PATH = os.path.join(os.getcwd(),"model","self_trained")
PICKLE_DIR = os.path.join(os.getcwd(),"pickle_files")
CSV_DIR = os.path.join(os.getcwd(),"csv_files")

# %%
if not os.path.exists(TEST_DIR):
    print("Testing data does not exists")
if not os.path.exists(TRAIN_DIR):
    print("Training data does not exists")
if not os.path.exists(MODEL_PATH):
    print("Model path does not exists")
    os.makedirs(MODEL_PATH)
    print("Model path created")
if not os.path.exists(PICKLE_DIR):
    os.makedirs(PICKLE_DIR)
if not os.path.exists(CSV_DIR):
    os.makedirs(CSV_DIR)
# Out:
# Testing data does not exists
# Training data does not exists
# Model path does not exists
# Model path created

# %%
# defining parameters for image data generator
gen_per_image = 1
gen_per_class = 200
rotation_range = 5
width_shift_range = 0.02
height_shift_range = 0.02
shear_range = 0.01
zoom_range = 0.05
horizontal_flip = False
fill_mode = "nearest"

# %%
# defining 3 functions on basis of which we will generate different images over the existing training images using the imagedatagenerator
def increase_brightness(img,value):
    hsv=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    h,s,v=cv2.split(hsv)
    lim=255-value
    v[v>lim]=255
    v[v<=lim]+=value
    
    final_hsv=cv2.merge((h,s,v))
    img=cv2.cvtColor(final_hsv,cv2.COLOR_HSV2BGR)
    return img
def change_contrast(img,level):
    img=Image.fromarray(img.astype('uint8'))
    factor=(259*(level+255))/(255*(259-level))
    def contrast(c):
        return 128+factor*(c-128)
    return np.array(img.point(contrast))
def pad_img(img):
    h, w = img.shape[:2]
    new_h = int((5 + secrets.randbelow(16)) * h / 100) + h
    new_w = int((5 + secrets.randbelow(16)) * w / 100) + w
    full_sheet = np.ones((new_h, new_w, 3)) * 255
    
    p_X = secrets.randbelow(new_h - img.shape[0])
    p_Y = secrets.randbelow(new_w - img.shape[1])
    
    full_sheet[p_X : p_X + img.shape[0], p_Y : p_Y + img.shape[1]] = img
    full_sheet = cv2.resize(full_sheet, (w, h), interpolation = cv2.INTER_AREA)
    return full_sheet.astype(np.uint8)
def preprocess_img(img):
    img = np.array(img)

    x = secrets.randbelow(2)

    if x == 0:
        # img = pad_img(img)
        img = increase_brightness(img, secrets.randbelow(26))
        img = change_contrast(img, secrets.randbelow(51))
    else:
        # img = pad_img(img)
        img = change_contrast(img, secrets.randbelow(51))
        img = increase_brightness(img, secrets.randbelow(26))

    return img

# %%
# initialising batch size,image size and number of epochs
BATCH_SIZE = 128
IMAGE_SIZE = 224
NUM_EPOCH = 25

# %%
datagen = ImageDataGenerator(
        rotation_range = rotation_range,
        width_shift_range = width_shift_range,
        height_shift_range = height_shift_range,
        shear_range = shear_range,
        zoom_range = zoom_range,
        horizontal_flip = horizontal_flip,
        fill_mode = fill_mode,
        validation_split = 0.2,
        preprocessing_function = preprocess_img)


train_data = datagen.flow_from_directory(TRAIN_DIR,
                                        target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                        batch_size=BATCH_SIZE,
                                        subset='training',shuffle=False)

valid_data = datagen.flow_from_directory(TRAIN_DIR,
                                        target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                        batch_size=BATCH_SIZE,
                                        subset='validation',shuffle=False)
# Out:
# Found 17943 images belonging to 10 classes.
# Found 4481 images belonging to 10 classes.

# %%
# Defining the Model 
model = Sequential()
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu', input_shape=(IMAGE_SIZE,IMAGE_SIZE,3), kernel_initializer='glorot_normal'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu', kernel_initializer='glorot_normal'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=256, kernel_size=2, padding='same', activation='relu', kernel_initializer='glorot_normal'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=512, kernel_size=2, padding='same', activation='relu', kernel_initializer='glorot_normal'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(500, activation='relu', kernel_initializer='glorot_normal'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax', kernel_initializer='glorot_normal'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 224, 224, 64)      832
#
#  max_pooling2d_8 (MaxPoolin  (None, 112, 112, 64)      0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 112, 112, 128)     32896
#
#  max_pooling2d_9 (MaxPoolin  (None, 56, 56, 128)       0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 56, 56, 256)       131328
#
#  max_pooling2d_10 (MaxPooli  (None, 28, 28, 256)       0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 512)       524800
#
#  max_pooling2d_11 (MaxPooli  (None, 14, 14, 512)       0
#  ng2D)
#
#  dropout_3 (Dropout)         (None, 14, 14, 512)       0
#
#  flatten_2 (Flatten)         (None, 100352)            0
#
#  dense_1 (Dense)             (None, 500)               50176500
#
#  dropout_4 (Dropout)         (None, 500)               0
#
#  dense_2 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 50871366 (194.06 MB)
# Trainable params: 50871366 (194.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# compiling the model 
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\manis\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
filepath = os.path.join(MODEL_PATH,"distracted-{epoch:02d}-{val_accuracy:.2f}.hdf5")
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
# fitting our model
model_history = model.fit(train_data,validation_data = valid_data,epochs=NUM_EPOCH,shuffle=True,callbacks=callbacks_list)
# Out:
# Epoch 1/25
# WARNING:tensorflow:From C:\Users\manis\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\manis\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 141/141 [==============================] - ETA: 0s - loss: 190.5287 - accuracy: 0.1312
# Epoch 1: val_accuracy improved from -inf to 0.15019, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-01-0.15.hdf5
# C:\Users\manis\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 141/141 [==============================] - 1242s 9s/step - loss: 190.5287 - accuracy: 0.1312 - val_loss: 2.2969 - val_accuracy: 0.1502
# Epoch 2/25
# 141/141 [==============================] - ETA: 0s - loss: 3.3637 - accuracy: 0.1102
# Epoch 2: val_accuracy improved from 0.15019 to 0.20375, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-02-0.20.hdf5
# 141/141 [==============================] - 1139s 8s/step - loss: 3.3637 - accuracy: 0.1102 - val_loss: 2.2566 - val_accuracy: 0.2037
# Epoch 3/25
# 141/141 [==============================] - ETA: 0s - loss: 2.7119 - accuracy: 0.1586
# Epoch 3: val_accuracy improved from 0.20375 to 0.27583, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-03-0.28.hdf5
# 141/141 [==============================] - 1117s 8s/step - loss: 2.7119 - accuracy: 0.1586 - val_loss: 1.9586 - val_accuracy: 0.2758
# Epoch 4/25
# 141/141 [==============================] - ETA: 0s - loss: 2.0438 - accuracy: 0.3426
# Epoch 4: val_accuracy did not improve from 0.27583
# 141/141 [==============================] - 1141s 8s/step - loss: 2.0438 - accuracy: 0.3426 - val_loss: 11.0191 - val_accuracy: 0.0857
# Epoch 5/25
# 141/141 [==============================] - ETA: 0s - loss: 1.7432 - accuracy: 0.4733
# Epoch 5: val_accuracy improved from 0.27583 to 0.66302, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-05-0.66.hdf5
# 141/141 [==============================] - 1135s 8s/step - loss: 1.7432 - accuracy: 0.4733 - val_loss: 0.9858 - val_accuracy: 0.6630
# Epoch 6/25
# 141/141 [==============================] - ETA: 0s - loss: 1.1695 - accuracy: 0.6017
# Epoch 6: val_accuracy improved from 0.66302 to 0.75519, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-06-0.76.hdf5
# 141/141 [==============================] - 1143s 8s/step - loss: 1.1695 - accuracy: 0.6017 - val_loss: 0.7189 - val_accuracy: 0.7552
# Epoch 7/25
# 141/141 [==============================] - ETA: 0s - loss: 0.8332 - accuracy: 0.7277
# Epoch 7: val_accuracy improved from 0.75519 to 0.84512, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-07-0.85.hdf5
# 141/141 [==============================] - 1143s 8s/step - loss: 0.8332 - accuracy: 0.7277 - val_loss: 0.4411 - val_accuracy: 0.8451
# Epoch 8/25
# 141/141 [==============================] - ETA: 0s - loss: 0.5577 - accuracy: 0.8174
# Epoch 8: val_accuracy improved from 0.84512 to 0.89913, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-08-0.90.hdf5
# 141/141 [==============================] - 1143s 8s/step - loss: 0.5577 - accuracy: 0.8174 - val_loss: 0.3044 - val_accuracy: 0.8991
# Epoch 9/25
# 141/141 [==============================] - ETA: 0s - loss: 0.4633 - accuracy: 0.8606
# Epoch 9: val_accuracy improved from 0.89913 to 0.95001, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-09-0.95.hdf5
# 141/141 [==============================] - 1539s 11s/step - loss: 0.4633 - accuracy: 0.8606 - val_loss: 0.1749 - val_accuracy: 0.9500
# Epoch 10/25
# 141/141 [==============================] - ETA: 0s - loss: 0.3507 - accuracy: 0.8992
# Epoch 10: val_accuracy improved from 0.95001 to 0.96095, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-10-0.96.hdf5
# 141/141 [==============================] - 1117s 8s/step - loss: 0.3507 - accuracy: 0.8992 - val_loss: 0.1360 - val_accuracy: 0.9609
# Epoch 11/25
# 141/141 [==============================] - ETA: 0s - loss: 0.2845 - accuracy: 0.9176
# Epoch 11: val_accuracy improved from 0.96095 to 0.96362, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-11-0.96.hdf5
# 141/141 [==============================] - 1110s 8s/step - loss: 0.2845 - accuracy: 0.9176 - val_loss: 0.1307 - val_accuracy: 0.9636
# Epoch 12/25
# 141/141 [==============================] - ETA: 0s - loss: 0.2372 - accuracy: 0.9282
# Epoch 12: val_accuracy improved from 0.96362 to 0.97344, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-12-0.97.hdf5
# 141/141 [==============================] - 1112s 8s/step - loss: 0.2372 - accuracy: 0.9282 - val_loss: 0.0921 - val_accuracy: 0.9734
# Epoch 13/25
# 141/141 [==============================] - ETA: 0s - loss: 0.2022 - accuracy: 0.9399
# Epoch 13: val_accuracy improved from 0.97344 to 0.98215, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-13-0.98.hdf5
# 141/141 [==============================] - 1116s 8s/step - loss: 0.2022 - accuracy: 0.9399 - val_loss: 0.0679 - val_accuracy: 0.9821
# Epoch 14/25
# 141/141 [==============================] - ETA: 0s - loss: 0.1894 - accuracy: 0.9490
# Epoch 14: val_accuracy improved from 0.98215 to 0.98594, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-14-0.99.hdf5
# 141/141 [==============================] - 1133s 8s/step - loss: 0.1894 - accuracy: 0.9490 - val_loss: 0.0601 - val_accuracy: 0.9859
# Epoch 15/25
# 141/141 [==============================] - ETA: 0s - loss: 0.1741 - accuracy: 0.9551
# Epoch 15: val_accuracy improved from 0.98594 to 0.98728, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-15-0.99.hdf5
# 141/141 [==============================] - 1126s 8s/step - loss: 0.1741 - accuracy: 0.9551 - val_loss: 0.0456 - val_accuracy: 0.9873
# Epoch 16/25
# 141/141 [==============================] - ETA: 0s - loss: 0.1589 - accuracy: 0.9561
# Epoch 16: val_accuracy improved from 0.98728 to 0.98884, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-16-0.99.hdf5
# 141/141 [==============================] - 1128s 8s/step - loss: 0.1589 - accuracy: 0.9561 - val_loss: 0.0442 - val_accuracy: 0.9888
# Epoch 17/25
# 141/141 [==============================] - ETA: 0s - loss: 0.1649 - accuracy: 0.9546
# Epoch 17: val_accuracy did not improve from 0.98884
# 141/141 [==============================] - 1151s 8s/step - loss: 0.1649 - accuracy: 0.9546 - val_loss: 0.0609 - val_accuracy: 0.9837
# Epoch 18/25
# 141/141 [==============================] - ETA: 0s - loss: 0.1595 - accuracy: 0.9597
# Epoch 18: val_accuracy did not improve from 0.98884
# 141/141 [==============================] - 1132s 8s/step - loss: 0.1595 - accuracy: 0.9597 - val_loss: 0.0933 - val_accuracy: 0.9779
# Epoch 19/25
# 141/141 [==============================] - ETA: 0s - loss: 0.1314 - accuracy: 0.9635
# Epoch 19: val_accuracy improved from 0.98884 to 0.99063, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-19-0.99.hdf5
# 141/141 [==============================] - 1130s 8s/step - loss: 0.1314 - accuracy: 0.9635 - val_loss: 0.0390 - val_accuracy: 0.9906
# Epoch 20/25
# 141/141 [==============================] - ETA: 0s - loss: 0.1187 - accuracy: 0.9684
# Epoch 20: val_accuracy did not improve from 0.99063
# 141/141 [==============================] - 1130s 8s/step - loss: 0.1187 - accuracy: 0.9684 - val_loss: 0.0605 - val_accuracy: 0.9844
# Epoch 21/25
# 141/141 [==============================] - ETA: 0s - loss: 0.1246 - accuracy: 0.9655
# Epoch 21: val_accuracy improved from 0.99063 to 0.99085, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-21-0.99.hdf5
# 141/141 [==============================] - 1698s 12s/step - loss: 0.1246 - accuracy: 0.9655 - val_loss: 0.0411 - val_accuracy: 0.9909
# Epoch 22/25
# 141/141 [==============================] - ETA: 0s - loss: 0.1472 - accuracy: 0.9659
# Epoch 22: val_accuracy did not improve from 0.99085
# 141/141 [==============================] - 2709s 19s/step - loss: 0.1472 - accuracy: 0.9659 - val_loss: 0.0435 - val_accuracy: 0.9879
# Epoch 23/25
# 141/141 [==============================] - ETA: 0s - loss: 0.1254 - accuracy: 0.9693
# Epoch 23: val_accuracy improved from 0.99085 to 0.99241, saving model to C:\Users\manis\Desktop\Driver_Detection\model\self_trained\distracted-23-0.99.hdf5
# 141/141 [==============================] - 35191s 251s/step - loss: 0.1254 - accuracy: 0.9693 - val_loss: 0.0277 - val_accuracy: 0.9924
# Epoch 24/25
# 141/141 [==============================] - ETA: 0s - loss: 0.1116 - accuracy: 0.9704
# Epoch 24: val_accuracy did not improve from 0.99241
# 141/141 [==============================] - 1146s 8s/step - loss: 0.1116 - accuracy: 0.9704 - val_loss: 0.0393 - val_accuracy: 0.9911
# Epoch 25/25
# 141/141 [==============================] - ETA: 0s - loss: 0.1013 - accuracy: 0.9746
# Epoch 25: val_accuracy did not improve from 0.99241
# 141/141 [==============================] - 1137s 8s/step - loss: 0.1013 - accuracy: 0.9746 - val_loss: 0.0616 - val_accuracy: 0.9833

# %%
# plotting training and validation accuracy
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(model_history.history['loss'], color='b', label="Training loss")
ax1.plot(model_history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, 25, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(model_history.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(model_history.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, 25, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %%
# defining function to print the confusion matrix
def getConfusionMatrix(confusion_matrix,class_names,figsize=(10,7),fontsize=15):
    df_cm=pd.DataFrame(confusion_matrix,index=class_names,columns=class_names)
    fig=plt.figure(figsize=figsize)
    try:
        heatmap=sns.heatmap(df_cm,annot=True,fmt="d")
    except ValueError:
        raise ValueError("Matix values are not integer")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    fig.savefig(os.path.join(MODEL_PATH,"confusion_matrix.png"))
    return fig

# %%
def printHeatMap(n_labels,n_predictions,class_names):
    labels = n_labels #sess.run(tf.argmax(n_labels, 1))
    predictions = n_predictions #sess.run(tf.argmax(n_predictions, 1))

#     confusion_matrix = sess.run(tf.contrib.metrics.confusion_matrix(labels, predictions))
    matrix=confusion_matrix(labels,predictions.argmax(axis=1))
    row_sum=np.sum(matrix,axis=1)
    w,h=matrix.shape
    c_m=np.zeros((w,h))
    
    for i in range(h):
        c_m[i]=matrix[i]*100/row_sum[i]
    c=c_m.astype(dtype=np.uint8)
    heatmap=getConfusionMatrix(c,class_names,figsize=(18,10),fontsize=20)

# %%
ypred=model.predict(valid_data)
valid_list=valid_data.classes.tolist()
y_pred_class=np.argmax(ypred,axis=1)
ytest=valid_list
# Out:
# 36/36 [==============================] - 93s 3s/step

# %%
class_names=list()
for name,idx in valid_data.class_indices.items():
    class_names.append(name)
print(class_names)
# Out:
# ['c0', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9']

# %%
printHeatMap(ytest,ypred,class_names)

# %%
# printing accuracy precision recall and F1 Score to analyse our model
accuracy=accuracy_score(ytest,y_pred_class)
precision = precision_score(ytest, y_pred_class,average='weighted')
recall=recall_score(ytest,y_pred_class,average='weighted')
f1=f1_score(ytest,y_pred_class,average='weighted')
print("Accuracy %f" %accuracy)
print("Precision %f" %precision)
print("Recall %f" %recall)
print("F1 Score %f" %f1)
# Out:
# Accuracy 0.983263
# Precision 0.983827
# Recall 0.983263
# F1 Score 0.983369

# %%
model.evaluate(valid_data)
# Out:
# 36/36 [==============================] - 265s 7s/step - loss: 0.0561 - accuracy: 0.9833
# [0.05612930655479431, 0.9832626581192017]
